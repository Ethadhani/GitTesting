# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
print("this test worked")
# Out:
# this test worked

# %%
xset = np.linspace(0,1000,999)

# %%
plt.plot(xset,xset)

# %%
print("it worked")
# Out:
# it worked
